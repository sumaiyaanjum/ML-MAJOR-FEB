# %% [markdown]
# <a href="https://colab.research.google.com/github/sumaiyaanjum/ML-MAJOR-FEB/blob/main/Sentiment_Analyis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install vaderSentiment
# Out:
# ...
#      |████████████████████████████████| 133kB 4.4MB/s
# ...

# %% [markdown]
# sentiment analysis: The process of determining whether the thing is positive,negative or neutral.
#
#
#
#   two types:
#   1.lexicon based approach :- *vader *textblob *afinn (calculates the sentiments from the orientation of a word or phrase)
#
#   2.machine learning algorithm :- *naive bayes *support vestor machine
#
#   vader:-  Valence Aware Dictionary And Estimation Reasoner
#   (focuses on compound scoring)

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
vs = SentimentIntensityAnalyzer()

# %%
text = 'the produst is really good'
vs.polarity_scores(text)
# Out:
# {'compound': 0.4927, 'neg': 0.0, 'neu': 0.556, 'pos': 0.444}

# %%
text1 = 'the produst is worst'
vs.polarity_scores(text1)
# Out:
# {'compound': -0.6249, 'neg': 0.577, 'neu': 0.423, 'pos': 0.0}

# %%
text2 = 'the produst is average'
vs.polarity_scores(text2)
# Out:
# {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0}

# %%
text3 = 'the produst is awesome'
vs.polarity_scores(text3)
# Out:
# {'compound': 0.6249, 'neg': 0.0, 'neu': 0.423, 'pos': 0.577}

# %%
text4 = "Awesome product, does not betray at any point, also has motion sensors meaning when you move up your hand to see the time the screen automatically lights up which is a really cool and amazing feature not found in other watches of this range. Absolutely loved this and highly recommend this. You wouldn't be disappointed or feel cheated"
vs.polarity_scores(text4)
# Out:
# {'compound': 0.9737, 'neg': 0.042, 'neu': 0.619, 'pos': 0.339}

# %%
text5 = 'Everything is fine'
vs.polarity_scores(text5)
# Out:
# {'compound': 0.2023, 'neg': 0.0, 'neu': 0.526, 'pos': 0.474}

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import os

# %%
#web scraping
url = 'https://inshorts.com/en/read/national'
news_data = []
news_category = url.split('/')[-1]
news_category
# Out:
# 'national'

# %%
url = 'https://inshorts.com/en/read/national'
news_data = []
news_category = url.split('/')[-1]
data = requests.get(url)
soup = BeautifulSoup(data.content)
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <style>
#     /* The Modal (background) */
#     .modal_contact {
#         display: none; /* Hidden by default */
#         position: fixed; /* Stay in place */
#         z-index: 8; /* Sit on top */
#         left: 0;
#         top: 0;
#         width: 100%; /* Full width */
#         height: 100%;
#         overflow: auto; /* Enable scroll if needed */
#         background-color: rgb(0,0,0); /* Fallback color */
#         background-color: rgba(0,0,0,0.4); /* Black w/ opacity */
#     }
#
#     /* Modal Content/Box */
#     .modal-content {
#         background-color: #fefefe;
#         margin: 15% auto;
#         padding: 20px !important;
#         padding-top: 0 !important;
#         /* border: 1px solid #888; */
#         text-align: center;
#         position: relative;
#         border-radius: 6px;
#     }
#
#     /* The Close Button */
#     .close {
#       left: 90%;
#       color: #aaa;
# ...

# %%
urls = ['https://inshorts.com/en/read/national',
        'https://inshorts.com/en/read/business',
        'https://inshorts.com/en/read/sports']
         
def build_dataset(urls):
  news_data = []
  for url in urls:
    news_category = url.split('/')[-1]
    data = requests.get(url)
    soup = BeautifulSoup(data.content)

    news_articles = [{'news_headline':headline.find('span',attrs={"itemprop":"headline"}).string,
                      'news_article':article.find('div',attrs={"itemprop":"articleBody"}).string,
                      'news_category':news_category}
                     
                     for headline,article in zip(soup.find_all('div',class_=["news-card-title news-right-box"]),
                                                 soup.find_all('div',class_=["news-card-content news-right-box"]))]
    news_articles = news_articles[0:20]
    news_data.extend(news_articles)

  df = pd.DataFrame(news_data)
  df = df[['news_headline','news_article','news_category']]
  return df

# %%
df = build_dataset(urls)
df.head()
# Out:
#                                        news_headline  ... news_category
# 0  Delhi reported record 25,500 COVID-19 cases, o...  ...      national
# 1  Rahul Gandhi cancels poll rallies in West Beng...  ...      national
# 2  Actual COVID-19 deaths in Delhi higher than re...  ...      national
# 3  Thrissur Pooram can't be cancelled, will cause...  ...      national
# 4  India's daily COVID-19 positivity rate has dou...  ...      national
#
# [5 rows x 3 columns]

# %%
df = build_dataset(urls)
df.tail()
# Out:
#                                         news_headline  ... news_category
# 55  Qatar aims to host COVID-19 free FIFA World Cu...  ...        sports
# 56  Daniel Sams joins RCB bubble after testing neg...  ...        sports
# 57  Bumrah is one of the best bowlers in death ove...  ...        sports
# 58  I couldn't care less, not interested at all: M...  ...        sports
# 59  CSK's Ngidi completes mandatory quarantine, be...  ...        sports
#
# [5 rows x 3 columns]

# %%
df.to_csv('news.csv',index=False)

# %%
import pandas as pd
df  = pd.read_csv('https://.github.com/sumaiyaanjum/ML-MAJOR-FEB/commit/e09f265e58bb5a99f02e0add87458e0de90dc5b1?branch=e09f265e58bb5a99f02e0add87458e0de90dc5b1&diff=unified')
df
# Out:
# ---------------------------------------------------------------------------
# UnicodeError                              Traceback (most recent call last)
# /usr/lib/python3.7/encodings/idna.py in encode(self, input, errors)
#     164                 if not (0 < len(label) < 64):
# --> 165                     raise UnicodeError("label empty or too long")
#     166             if len(labels[-1]) >= 64:
#
# UnicodeError: label empty or too long
#
# The above exception was the direct cause of the following exception:
#
# UnicodeError                              Traceback (most recent call last)
# <ipython-input-34-8b9efd8989f4> in <module>()
#       1 import pandas as pd
# ----> 2 df  = pd.read_csv('https://.github.com/sumaiyaanjum/ML-MAJOR-FEB/commit/e09f265e58bb5a99f02e0add87458e0de90dc5b1?branch=e09f265e58bb5a99f02e0add87458e0de90dc5b1&diff=unified')
#       3 df
#
# ...

# %%
import nltk
nltk.download('stopwords')
stopword_list = nltk.corpus.stopwords.words('english')
stopword_list
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
# ...

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
s = nltk.corpus.stopwords.words('english')
len(s)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 179

# %%
import nltk
nltk.download('stopwords')
stopword_list = nltk.corpus.stopwords.words('english')
stopword_list.remove('no')
stopword_list.remove('not')
len(stopword_list)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 177

# %%
def html_tag(text):
  soup = BeautifulSoup(text,"html.parser")
  new_text = soup.get_text()
  return new_text

html_tag('<html><h2> Some important ifno</h2><html>')
# Out:
# ' Some important ifno'

# %%
# !pip install contractions
import contractions
def con(text):
  expand = contractions.fix(text)
  return expand
con("y'all can't expant I'd think")
# Out:
# ...
#      |████████████████████████████████| 327kB 5.6MB/s
# ...
#      |████████████████████████████████| 286kB 7.3MB/s
# ...
#   Created wheel for pyahocorasick: filename=pyahocorasick-1.4.2-cp37-cp37m-linux_x86_64.whl size=85393 sha256=21e4688f3a78c9094ec50011aa105a34359d1649ed67d71c11f6f32129874d20
#   Stored in directory: /root/.cache/pip/wheels/3a/03/34/77e3ece0bba8b86bfac88a79f923b36d805cad63caeba38842
# Successfully built pyahocorasick
# ...
# 'you all can not expant I would think'

# %%
# !pip install contractions
import contractions
def con(text):
  expand = contractions.fix(text)
  return expand
con("y'all can't expant I'd think")
# Out:
# ...
# 'you all can not expant I would think'

# %%
import re 
def remove_sp(text):
  pattern = r'[^A-Za-z0-9\s]' 
  text = re.sub(pattern,'',text)
  return text

remove_sp("sumaiya@$*%")
# Out:
# 'sumaiya'

# %%
from nltk.tokenize.toktok import ToktokTokenizer
tokenizer = ToktokTokenizer

# %%
def remove_stopwords(text):
  token = tokenizer.tokenize(text)
  tokens = [token.strip() for token in tokens]
  filtered_tokens = [token for token in tokens if token not in stopword_list]
  filtered_text = ' '.join(filtered_tokens)
  return filtered_text

# %%
df.news_headline = df.news_headline.apply(lambda x:x.lower())
df.news_article = df.news_article.apply(lambda x:x.lower())

df.news_headline = df.news_headline.apply(html_tag)
df.news_article = df.news_article.apply(html_tag)

df.news_headline = df.news_headline.apply(con)
df.news_article = df.news_article.apply(con)

df.news_headline = df.news_headline.apply(remove_sp)
df.news_article = df.news_article.apply(remove_sp)

df.news_headline = df.news_headline.apply(remove_stopwords)
df.news_article = df.news_article.apply(remove_stopwords)

df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-02d5ca9ca92a> in <module>()
#      12 df.news_article = df.news_article.apply(remove_sp)
#      13
# ---> 14 df.news_headline = df.news_headline.apply(remove_stopwords)
#      15 df.news_article = df.news_article.apply(remove_stopwords)
#      16
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4211             else:
#    4212                 values = self.astype(object)._values
# -> 4213                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4214
#    4215         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-38-90a10aac22ee> in remove_stopwords(text)
#       1 def remove_stopwords(text):
# ----> 2   token = tokenizer.tokenize(text)
# ...

# %%
df['compound'] = df['news_article'].apply(lambda x: vs.polarity_scores(x)['compound'])

# %%
df.head()
# Out:
#                                        news_headline  ... compound
# 0  actual covid19 deaths in delhi higher than rep...  ...  -0.8689
# 1  rahul gandhi cancels poll rallies in west beng...  ...  -0.3182
# 2  delhi reported record 25500 covid19 cases only...  ...   0.4767
# 3  thrissur pooram can not be cancelled will beca...  ...   0.2359
# 4  indias daily covid19 positivity rate has doubl...  ...   0.9001
#
# [5 rows x 4 columns]
